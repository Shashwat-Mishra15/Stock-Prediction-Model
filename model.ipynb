# %% [markdown]
# ### Keras and Tenserflow >2.0

# %%
import pandas_datareader as pdr
from alpha_vantage.timeseries datetime import datetime

# %%
api_key= 'O2KQUT15SWGGMOP9'
df = pdr.DataReader('AAPL','av', start= datetime(2015, 1, 1), api_key=api_key)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 api_key= 'O2KQUT15SWGGMOP9'
# ----> 2 df = pdr.DataReader('AAPL','av', start= datetime(2015, 1, 1), api_key=api_key)
#
# File c:\Users\SHASHWAT\anaconda3\Lib\site-packages\pandas\util\_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# File c:\Users\SHASHWAT\anaconda3\Lib\site-packages\pandas_datareader\data.py:367, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     365 if data_source not in expected_source:
#     366     msg = "data_source=%r is not implemented" % data_source
# --> 367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
# ...
